# %%
documents_with_marked_terms = []
documents_with_marked_terms.append([])
number_of_document = 0

with open("C:\DB\kurgansky_lemmas_0.txt", encoding="utf-8") as f:
    for paragraph in f:
        for word in paragraph.split():
            if word == "########" or '\ufeff########':
                documents_with_marked_terms.append([])
                number_of_document += 1
            else:
                for i in ['_PREP', '_X', '_ADJ_PRONOUN', '_PUNCT', '_NOUN_PRONOUN', '_CONJ']:
                    pattern = re.compile(i)
                    if pattern.search(word):
                        break
                    else:
                        documents_with_marked_terms[number_of_document].append(re.sub('_.*','', word))

# %%
for number_of_document in len(documents_with_marked_terms):
    for word in documents_with_marked_terms[i]

# %%
documents_with_marked_terms[11]
# Out:
# ['гей_NOUN',
#  'элита_NOUN',
#  'россия_NOUN',
#  ',_PUNCT',
#  'первый_ADJ',
#  'десяток_NOUN',
#  '._PUNCT',
#  'сторонник_NOUN',
#  'однополый_ADJ',
#  'любовь_NOUN',
#  'входить_VERB',
#  'в_PREP',
#  'список_NOUN',
#  'Forbes_X',
#  ',_PUNCT',
#  'управлять_VERB',
#  'банка_NOUN',
#  ',_PUNCT',
#  'завод_NOUN',
#  ',_PUNCT',
#  'аэропорт_NOUN',
#  'и_CONJ',
#  'верфь_NOUN',
#  '._PUNCT',
#  'отбиваться_ADVPARTICIPLE',
#  'от_PREP',
#  'нападки_NOUN',
#  'западный_ADJ',
#  'журналист_NOUN',
#  ',_PUNCT',
#  'упрекать_PARTICIPLE',
#  'он_NOUN_PRONOUN',
#  'в_PREP',
#  'нетерпимость_NOUN',
#  'к_PREP',
#  'секс_NOUN',
#  '-_X',
#  'меньшинство_NOUN',
#  ',_PUNCT',
#  'президент_NOUN',
#  'владимир_NOUN',
#  'путин_NOUN',
#  'неоднократно_ADV',
#  'заявлять_VERB',
#  ',_PUNCT',
#  'что_CONJ',
#  'относиться_VERB',
#  'к_PREP',
#  'они_NOUN_PRONOUN',
#  'со_PREP',
#  'весь_ADJ_PRONOUN',
#  'уважение_NOUN',
#  '._PUNCT',
#  'в_PREP',
#  'частность_NOUN',
#  ',_PUNCT',
#  'в_PREP',
#  'интервью_NOUN',
#  '"_PUNCT',
#  'первый_ADJ',
#  'канал_NOUN',
#  '"_PUNCT',
#  'и_CONJ',
#  'агентство_NOUN',
#  'Associated_X',
#  'Press_X',
#  'перед_PREP',
#  'сочинский_ADJ',
#  'олимпиада_NOUN',
#  'он_NOUN_PRONOUN',
#  'подчеркивать_VERB',
#  ',_PUNCT',
#  'что_CONJ',
#  'российский_ADJ',
#  'сторонник_NOUN',
#  'гомосексуализм_NOUN',
#  '-"_X',
#  'полноценный_ADJ',
#  'и_CONJ',
#  'равный_ADJ',
#  'в_PREP',
#  'право_NOUN',
#  'гражданин_NOUN',
#  '",_X',
#  'а_CONJ',
#  'лично_ADV',
#  'у_PREP',
#  'он_NOUN_PRONOUN',
#  'с_PREP',
#  'гей_NOUN',
#  '"_PUNCT',
#  'абсолютно_ADV',
#  'нормальный_ADJ',
#  'отношение_NOUN',
#  '"_PUNCT',
#  '._PUNCT',
#  'путин_NOUN',
#  'правый_ADJ',
#  ',_PUNCT',
#  'и_CONJ',
#  'тот_ADJ_PRONOUN',
#  'иметься_VERB',
#  'множество_NOUN',
#  'подтверждение_NOUN',
#  '._PUNCT',
#  'среди_PREP',
#  'чиновник_NOUN',
#  'и_CONJ',
#  'миллиардер_NOUN',
#  'российский_ADJ',
#  'федерация_NOUN',
#  'наблюдаться_VERB',
#  'множество_NOUN',
#  'ценитель_NOUN',
#  'однополый_ADJ',
#  'любовь_NOUN',
#  ',_PUNCT',
#  'некоторый_ADJ_PRONOUN',
#  'из_PREP',
#  'который_ADJ_PRONOUN',
#  'сделать_VERB',
#  'головокружительный_ADJ',
#  'карьера_NOUN',
#  '._PUNCT',
#  'изучать_ADVPARTICIPLE',
#  'их_ADJ_PRONOUN',
#  'биография_NOUN',
#  ',_PUNCT',
#  'редакция_NOUN',
#  'агентство_NOUN',
#  '"_PUNCT',
#  'руспрес_NOUN',
#  '"_PUNCT',
#  'составлять_VERB',
#  'рейтинг_NOUN',
#  ',_PUNCT',
#  'который_ADJ_PRONOUN',
#  'включать_VERB',
#  'десять_NUM',
#  'наиболее_ADV',
#  'яркий_ADJ',
#  'представитель_NOUN',
#  'гей_NOUN',
#  '-_X',
#  'сообщество_NOUN',
#  'из_PREP',
#  'российский_ADJ',
#  'бизнес_NOUN',
#  '._PUNCT',
#  '1_X',
#  'место_NOUN',
#  '._PUNCT',
#  'герман_NOUN',
#  'греф_NOUN',
#  '._PUNCT',
#  'первый_ADJ',
#  'строчка_NOUN',
#  'занимать_VERB',
#  'наиболее_ADV',
#  'высокопоставленный_ADJ',
#  'представитель_NOUN',
#  'сообщество_NOUN',
#  '—_PUNCT',
#  'глава_NOUN',
#  'сбербанк_NOUN',
#  'герман_NOUN',
#  'греф_NOUN',
#  ',_PUNCT',
#  'перемещаться_PARTICIPLE',
#  'на_PREP',
#  'нынешний_ADJ',
#  'должность_NOUN',
#  'с_PREP',
#  'пост_NOUN',
#  'министр_NOUN',
#  'экономический_ADJ',
#  'развитие_NOUN',
#  'и_CONJ',
#  'торговля_NOUN',
#  '._PUNCT',
#  'финансовый_ADJ',
#  'учреждение_NOUN',
#  ',_PUNCT',
#  'возглавлять_PARTICIPLE',
#  'греф_NOUN',
#  ',_PUNCT',
#  'являться_VERB',
#  'один_ADJ_PRONOUN',
#  'из_PREP',
#  'крупный_ADJ',
#  'банк_NOUN',
#  'россия_NOUN',
#  '._PUNCT',
#  'его_ADJ_PRONOUN',
#  'актив_NOUN',
#  'на_PREP',
#  'сегодняшний_ADJ',
#  'день_NOUN',
#  'превышать_VERB',
#  '18_X',
#  'трлн_NOUN',
#  '._PUNCT',
#  'руб_NOUN',
#  ',_PUNCT',
#  'а_CONJ',
#  'количество_NOUN',
#  'сотрудник_NOUN',
#  'приближаться_VERB',
#  'к_PREP',
#  'четверть_NOUN',
#  'миллион_NOUN',
#  '._PUNCT',
#  'после_PREP',
#  'приход_NOUN',
#  'греф_NOUN',
#  'банк_NOUN',
#  'вести_VERB',
#  'активный_ADJ',
#  'экспансия_NOUN',
#  ',_PUNCT',
#  'приобретать_ADVPARTICIPLE',
#  'российский_ADJ',
#  'инвестиционный_ADJ',
#  'компания_NOUN',
#  '"_PUNCT',
#  'тройка_NOUN',
#  '-_X',
#  'диалог_NOUN',
#  '",_X',
#  'австрийский_ADJ',
#  'банк_NOUN',
#  'VBI_X',
#  ',_PUNCT',
#  'швейцарский_ADJ',
#  'SLB_X',
#  'и_CONJ',
#  'австрийский_ADJ',
#  'Denizbank_X',
#  '._PUNCT',
#  'мочь_VERB',
#  'ли_CONJ',
#  'помешать_INFN',
#  'греф_NOUN',
#  'сделать_INFN',
#  'этот_ADJ_PRONOUN',
#  'приобретение_NOUN',
#  'слух_NOUN',
#  'о_PREP',
#  'его_ADJ_PRONOUN',
#  'половой_ADJ',
#  'ориентация_NOUN',
#  ',_PUNCT',
#  'или_CONJ',
#  'даже_PART',
#  'ее_ADJ_PRONOUN',
#  'оглашение_NOUN',
#  ',_PUNCT',
#  'сделать_PARTICIPLE',
#  'на_PREP',
#  'радио_NOUN',
#  'Finafm_X',
#  'основатель_NOUN',
#  'правозащитный_ADJ',
#  'портал_NOUN',
#  'GayRussia_X',
#  '._PUNCT',
#  'Ru_X',
#  'николай_NOUN',
#  'алексеев_NOUN',
#  '?_PUNCT',
#  'ни_PART',
#  'в_PREP',
#  'кой_ADJ_PRONOUN',
#  'мера_NOUN',
#  '!_PUNCT',
#  'как_ADV_PRONOUN',
#  'и_CONJ',
#  'постоянный_ADJ',
#  'обсуждение_NOUN',
#  'в_PREP',
#  'офис_NOUN',
#  'сбербанк_NOUN',
#  'персона_NOUN',
#  'молодой_ADJ',
#  'и_CONJ',
#  'симпатичный_ADJ',
#  'референт_NOUN',
#  'т_NOUN',
#  '._PUNCT',
#  ',_PUNCT',
#  'пользоваться_PARTICIPLE',
#  'особый_ADJ',
#  'доверие_NOUN',
#  'начальство_NOUN',
#  '._PUNCT',
#  '2_X',
#  'место_NOUN',
#  '._PUNCT',
#  'михаил_NOUN',
#  'прохоров_NOUN',
#  '._PUNCT',
#  'долларовый_ADJ',
#  'миллиардер_NOUN',
#  'и_CONJ',
#  'бывший_ADJ',
#  'владелец_NOUN',
#  '"_PUNCT',
#  'норильский_ADJ',
#  'никель_NOUN',
#  '"_PUNCT',
#  'мочь_VERB',
#  'бы_PART',
#  'поспорить_INFN',
#  'с_PREP',
#  'греф_NOUN',
#  'за_PREP',
#  'первый_ADJ',
#  'место_NOUN',
#  '._PUNCT',
#  'прохоров_NOUN',
#  'покидать_VERB',
#  'никелевый_ADJ',
#  'бизнес_NOUN',
#  ',_PUNCT',
#  'проваливать_VERB',
#  'проект_NOUN',
#  'выпуск_NOUN',
#  '"_PUNCT',
#  'е_NOUN',
#  '-_X',
#  'мобиль_NOUN',
#  '"_PUNCT',
#  'и_CONJ',
#  'потерять_VERB',
#  'позиция_NOUN',
#  'в_PREP',
#  'собственный_ADJ',
#  'либеральный_ADJ',
#  'партия_NOUN',
#  '"_PUNCT',
#  'гражданский_ADJ',
#  'платформа_NOUN',
#  '"_PUNCT',
#  '._PUNCT',
#  'руководство_NOUN',
#  'федерация_NOUN',
#  'биатлон_NOUN',
#  'приходиться_VERB',
#  'оставлять_INFN',
#  'после_PREP',
#  'то_NOUN_PRONOUN',
#  ',_PUNCT',
#  'как_CONJ',
#  'дарья_NOUN',
#  'домрачев_NOUN',
#  ',_PUNCT',
#  'который_ADJ_PRONOUN',
#  'федерация_NOUN',
#  'упускать_VERB',
#  'в_PREP',
#  'белоруссия_NOUN',
#  ',_PUNCT',
#  'выигрывать_VERB',
#  'на_PREP',
#  'олимпиада_NOUN',
#  'в_PREP',
#  'сочи_NOUN',
#  'три_NUM',
#  'гонка_NOUN',
#  ',_PUNCT',
#  'а_CONJ',
#  'ее_ADJ_PRONOUN',
#  'бывший_ADJ',
#  'российский_ADJ',
#  'товарищ_NOUN',
#  '—_PUNCT',
#  'только_PART',
#  'один_ADJ_PRONOUN',
#  '._PUNCT',
#  'купить_PARTICIPLE',
#  'прохоров_NOUN',
#  'в_PREP',
#  'сша_NOUN',
#  'баскетбольный_ADJ',
#  'клуб_NOUN',
#  'Brooklyn_X',
#  'Nets_X',
#  'выступать_VERB',
#  'слабо_ADV',
#  '._PUNCT',
#  'но_CONJ',
#  'если_CONJ',
#  'судить_INFN',
#  'исключительно_ADV',
#  'по_PREP',
#  'личный_ADJ',
#  'деньги_NOUN',
#  ',_PUNCT',
#  'среди_PREP',
#  'гей_NOUN',
#  'россия_NOUN',
#  'прохоров_NOUN',
#  'до_PREP',
#  'сей_ADJ_PRONOUN',
#  'самый_ADJ_PRONOUN',
#  'состоятельный_ADJ',
#  '._PUNCT',
#  'по_PREP',
#  'данные_NOUN',
#  'Forbes_X',
#  ',_PUNCT',
#  'в_NOUN',
#  '2008_X',
#  '-_X',
#  '2009_X',
#  'гг_X',
#  '._PUNCT',
#  'он_NOUN_PRONOUN',
#  'являться_VERB',
#  'богатый_ADJ',
#  'олигарх_NOUN',
#  'россия_NOUN',
#  ',_PUNCT',
#  'в_PREP',
#  '2010_X',
#  '-_X',
#  '2011_X',
#  'гг_X',
#  '._PUNCT',
#  'входить_VERB',
#  'в_PREP',
#  'их_ADJ_PRONOUN',
#  'первый_ADJ',
#  'тройка_NOUN',
#  ',_PUNCT',
#  'еще_ADV',
#  'в_PREP',
#  'прошлый_ADJ',
#  'год_NOUN',
#  'располагать_VERB',
#  'капитал_NOUN',
#  'в_PREP',
#  '$_X',
#  '13_X',
#  'млрд_NOUN',
#  '._PUNCT',
#  'немало_NUM',
#  'красавица_NOUN',
#  'пытаться_VERB',
#  'подводить_INFN',
#  'под_PREP',
#  'венец_NOUN',
#  'старый_ADJ',
#  'холостяк_NOUN',
#  'прохоров_NOUN',
#  ',_PUNCT',
#  'но_CONJ',
#  'безуспешно_ADV',
#  '._PUNCT',
#  'он_NOUN_PRONOUN',
#  'настолько_ADV',
#  'равнодушный_ADJ',
#  'к_PREP',
#  'женский_ADJ',
#  'прелесть_NOUN',
#  ',_PUNCT',
#  'что_CONJ',
#  ',_PUNCT',
#  'приглашать_ADVPARTICIPLE',
#  'к_PREP',
#  'себя_NOUN_PRONOUN',
#  'в_PREP',
#  'куршевельский_ADJ',
#  'номер_NOUN',
#  'пятеро_NUM',
#  'барышня_NOUN',
#  ',_PUNCT',
#  'попросить_VERB',
#  'они_NOUN_PRONOUN',
#  'лишь_PART',
#  'почитать_INFN',
#  'вслух_ADV',
#  'русский_ADJ',
#  'классика_NOUN',
#  '._PUNCT',
#  '3_X',
#  'место_NOUN',
#  '._PUNCT',
#  'владислав_NOUN',
#  'резник_NOUN',
#  '._PUNCT',
#  'замыкать_VERB',
#  'тройка_NOUN',
#  'лидер_NOUN',
#  'старинный_ADJ',
#  'приятель_NOUN',
#  'греф_NOUN',
#  'и_CONJ',
#  'признанный_ADJ',
#  'лидер_NOUN',
#  '"_PUNCT',
#  'голубой_ADJ',
#  'лобби_NOUN',
#  '"_PUNCT',
#  'в_PREP',
#  'государственный_ADJ',
#  'дума_NOUN',
#  ',_PUNCT',
#  'первый_ADJ',
#  'заместитель_NOUN',
#  'председатель_NOUN',
#  'комитет_NOUN',
#  'по_PREP',
#  'финансовый_ADJ',
#  'рынок_NOUN',
#  'и_CONJ',
#  'член_NOUN',
#  'высокий_ADJ',
#  'совет_NOUN',
#  '"_PUNCT',
#  'единый_ADJ',
#  'россия_NOUN',
#  '"_PUNCT',
#  'владислав_NOUN',
#  'резник_NOUN',
#  '._PUNCT',
#  'это_PART',
#  'не_PART',
#  'только_PART',
#  'один_ADJ_PRONOUN',
#  'из_PREP',
#  'влиятельный_ADJ',
#  'парламентарий_NOUN',
#  ',_PUNCT',
#  'но_CONJ',
#  'и_CONJ',
#  'едва_ADV',
#  'ли_PART',
#  'богатый_ADJ',
#  'политик_NOUN',
#  'россия_NOUN',
#  '._PUNCT',
#  'рублевый_ADJ',
#  'миллиардер_NOUN',
#  'резник_NOUN',
#  'приходить_VERB',
#  'в_PREP',
#  'дума_NOUN',
#  'с_PREP',
#  'пост_NOUN',
#  'председатель_NOUN',
#  'совет_NOUN',
#  'директор_NOUN',
#  'страховой_ADJ',
#  'общество_NOUN',
#  '"_PUNCT',
#  'русь_NOUN',
#  '",_X',
#  'где_ADV_PRONOUN',
#  'некогда_ADV_PRONOUN',
#  'его_ADJ_PRONOUN',
#  'подчиненный_NOUN',
#  'быть_VERB',
#  'молодой_ADJ',
#  'талантливый_ADJ',
#  'юрист_NOUN',
#  'дмитрий_NOUN',
#  'медведев_NOUN',
#  '._PUNCT',
#  'сейчас_ADV',
#  'у_PREP',
#  'резник_NOUN',
#  'только_PART',
#  'согласно_PREP',
#  'официальный_ADJ',
#  'декларация_NOUN',
#  'о_PREP',
#  'доход_NOUN',
#  'быть_VERB',
#  'вилла_NOUN',
#  ',_PUNCT',
#  'квартира_NOUN',
#  ',_PUNCT',
#  '16_X',
#  'земельный_ADJ',
#  'участок_NOUN',
#  'и_CONJ',
#  '24_X',
#  'автомобиль_NOUN',
#  'в_PREP',
#  'россия_NOUN',
#  ',_PUNCT',
#  'апартамент_NOUN',
#  'в_PREP',
#  'сша_NOUN',
#  '._PUNCT',
#  'и_CONJ',
#  'сверх_PREP',
#  'то_NOUN_PRONOUN',
#  '—_PUNCT',
#  'оформлять_PARTICIPLE',
#  'на_PREP',
#  'фирма_NOUN',
#  'поместье_NOUN',
#  'на_PREP',
#  'остров_NOUN',
#  'мальорка_NOUN',
#  '._PUNCT',
#  'попытка_NOUN',
#  'испанский_ADJ',
#  'полиция_NOUN',
#  'зачищать_INFN',
#  'этот_ADJ_PRONOUN',
#  'угодье_NOUN',
#  ',_PUNCT',
#  'объявлять_ADVPARTICIPLE',
#  'они_NOUN_PRONOUN',
#  'заповедник_NOUN',
#  '"_PUNCT',
#  'русский_ADJ',
#  'мафия_NOUN',
#  '",_X',
#  'проваливаться_VERB',
#  '—_PUNCT',
#  'уж_PART',
#  'больно_ADV',
#  'высокий_ADJ',
#  'покровительство_NOUN',
#  'иметь_VERB',
#  'нетрадиционный_ADJ',
#  'депутат_NOUN',
#  'российский_ADJ',
#  'парламент_NOUN',
#  '._PUNCT',
#  '4_X',
#  'место_NOUN',
#  '._PUNCT',
#  'олег_NOUN',
#  'тиньков_NOUN',
#  '._PUNCT',
#  'экс_NOUN',
#  '-_X',
#  'торговец_NOUN',
#  'пельмень_NOUN',
#  '"_PUNCT',
#  'дарья_NOUN',
#  '"_PUNCT',
#  'и_CONJ',
#  'пиво_NOUN',
#  '"_PUNCT',
#  'тинькофф_NOUN',
#  '",_X',
#  'основатель_NOUN',
#  'сеть_NOUN',
#  'одноименный_ADJ',
#  'пивной_ADJ',
#  'ресторан_NOUN',
#  ',_PUNCT',
#  'а_CONJ',
#  'теперь_ADV',
#  'банкир_NOUN',
#  'и_CONJ',
#  'владелец_NOUN',
#  'велосипедный_ADJ',
#  'команда_NOUN',
#  'олег_NOUN',
#  'тиньков_NOUN',
#  'формально_ADV',
#  'богатый_ADJ',
#  'резник_NOUN',
#  '._PUNCT',
#  'финансист_NOUN',
#  'давно_ADV',
#  'обосновываться_VERB',
#  'в_PREP',
#  'клуб_NOUN',
#  'долларовый_ADJ',
#  'миллиардер_NOUN',
#  'со_PREP',
#  'свой_ADJ_PRONOUN',
#  '$_X',
#  '1_X',
#  ',_PUNCT',
#  '8_X',
#  'млрд_NOUN',
#  ',_PUNCT',
#  'но_CONJ',
#  'его_ADJ_PRONOUN',
#  'политический_ADJ',
#  'влияние_NOUN',
#  'и_CONJ',
#  'лоббистский_ADJ',
#  'возможность_NOUN',
#  'небольшой_ADJ',
#  ',_PUNCT',
#  'а_CONJ',
#  'потому_ADV_PRONOUN',
#  'в_PREP',
#  'рейтинг_NOUN',
#  'он_NOUN_PRONOUN',
#  'низкий_ADJ',
#  '._PUNCT',
#  'в_PREP',
#  'октябрь_NOUN',
#  '2011_X',
#  'год_NOUN',
#  'тиньков_NOUN',
#  'быть_VERB',
#  'отмечать_PARTICIPLE',
#  'журнал_NOUN',
#  '"_PUNCT',
#  'Forbes_X',
#  '"_PUNCT',
#  'как_ADV_PRONOUN',
#  'один_ADJ_PRONOUN',
#  'из_PREP',
#  '9_X',
#  'самый_ADJ_PRONOUN',
#  'необычный_ADJ',
#  'российский_ADJ',
#  'бизнесмен_NOUN',
#  '—_PUNCT',
#  'сумасброд_NOUN',
#  ',_PUNCT',
#  'чудак_NOUN',
#  'и_CONJ',
#  'эксцентрик_NOUN',
#  '._PUNCT',
#  'в_PREP',
#  'начало_NOUN',
#  'март_NOUN',
#  '2013_X',
#  'год_NOUN',
#  'сообщать_VERB',
#  'о_PREP',
#  'запуск_NOUN',
#  'новый_ADJ',
#  'авиакомпания_NOUN',
#  'Tinkoff_X',
#  'Airlinesна_X',
#  'самый_ADJ_PRONOUN',
#  'дело_NOUN',
#  'являться_PARTICIPLE',
#  'маркетинговый_ADJ',
#  'название_NOUN',
#  'новый_ADJ',
#  'карточный_ADJ',
#  'продукт_NOUN',
#  'All_X',
#  'Airlines_X',
#  'банк_NOUN',
#  'тинькофф_NOUN',
#  '._PUNCT',
#  'кредитный_ADJ',
#  'система_NOUN',
#  '._PUNCT',
#  'в_PREP',
#  'декабрь_NOUN',
#  '2013_X',
#  'год_NOUN',
#  'по_PREP',
#  'версия_NOUN',
#  '"_PUNCT',
#  'Forbes_X',
#  '"_PUNCT',
#  'быть_VERB',
#  'признавать_PARTICIPLE',
#  '"_PUNCT',
#  'пионер_NOUN',
#  'год_NOUN',
#  '"_PUNCT',
#  'за_PREP',
#  'IPO_X',
#  'ТКС_X',
#  '-_X',
#  'банк_NOUN',
#  '._PUNCT',
#  'в_PREP',
#  'прошлый_ADJ',
#  'тиньков_NOUN',
#  'считаться_VERB',
#  'строгий_ADJ',
#  'гетеросексуал_NOUN',
#  ',_PUNCT',
#  'но_CONJ',
#  'недавно_ADV',
#  'признаваться_VERB',
#  'в_PREP',
#  'свой_ADJ_PRONOUN',
#  'нетрадиционный_ADJ',
#  'ориентация_NOUN',
#  '._PUNCT',
#  'правда_ADV',
#  ',_PUNCT',
#  'вскоре_ADV',
#  'последовать_VERB',
#  'опровержение_NOUN',
#  ',_PUNCT',
#  'но_CONJ',
#  'от_PREP',
#  'имя_NOUN',
#  'анонимный_ADJ',
#  'сотрудник_NOUN',
#  'пресс-служба_NOUN',
#  'банк_NOUN',
#  '"_PUNCT',
#  'тинькофф_NOUN',
#  '._PUNCT',
#  'кредитный_ADJ',
#  'система_NOUN',
#  '",_X',
#  'что_CONJ',
#  'позволять_VERB',
#  'считать_INFN',
#  'владелец_NOUN',
#  'бизнес_NOUN',
#  'по_PREP',
#  'крайний_ADJ',
#  'мера_NOUN',
#  'бисексуальный_ADJ',
#  '._PUNCT',
#  '5_X',
#  'место_NOUN',
#  '._PUNCT',
#  'борис_NOUN',
#  'шпигель_NOUN',
#  '._PUNCT',
#  'следовать_PARTICIPLE',
#  'за_PREP',
#  'тиньков_NOUN',
#  ',_PUNCT',
#  'пятый_ADJ',
#  'позиция_NOUN',
#  'занимать_VERB',
#  'бывший_ADJ',
#  'секретарь_NOUN',
#  'хмельницкий_NOUN',
#  'горком_NOUN',
#  'комсомол_NOUN',
#  ',_PUNCT',
#  'председатель_NOUN',
#  'конгресс_NOUN',
#  'еврейский_ADJ',
#  'организация_NOUN',
#  'россия_NOUN',
#  'и_CONJ',
#  'сенатор_NOUN',
#  'от_PREP',
#  'пензенский_ADJ',
#  'область_NOUN',
#  ',_PUNCT',
#  'основатель_NOUN',
#  'фармацевтический_ADJ',
#  'корпорация_NOUN',
#  '"_PUNCT',
#  'биотэк_NOUN',
#  '"(_X',
#  'годовой_ADJ',
#  'доход_NOUN',
#  'до_PREP',
#  '$_X',
#  '400_X',
#  'млн_X',
#  '.)_X',
#  'борис_NOUN',
#  'шпигель_NOUN',
#  '._PUNCT',
#  'если_CONJ',
#  'поверять_INFN',
#  'в_PREP',
#  'подлинность_NOUN',
#  'опубликовывать_PARTICIPLE',
#  'в_PREP',
#  'сеть_NOUN',
#  'копия_NOUN',
#  'приговор_NOUN',
#  'первомайский_ADJ',
#  'районный_ADJ',
#  'народный_ADJ',
#  'суд_NOUN',
#  'город_NOUN',
#  'москва_NOUN',
#  ',_PUNCT',
#  'господин_NOUN',
#  'шпигель_NOUN',
#  'в_PREP',
#  '1982_X',
#  'год_NOUN',
#  'быть_VERB',
#  'осуждать_PARTICIPLE',
#  'за_PREP',
#  'растление_NOUN',
#  'юный_ADJ',
#  'комсомолец_NOUN',
#  '._PUNCT',
#  'впоследствии_ADV',
#  ',_PUNCT',
#  'быть_ADVPARTICIPLE',
#  'продюсер_NOUN',
#  'свой_ADJ_PRONOUN',
#  'зять_NOUN',
#  '—_PUNCT',
#  'считаться_PARTICIPLE',
#  'гей_NOUN',
#  'певец_NOUN',
#  'николай_NOUN',
#  'басков_NOUN',
#  ',_PUNCT',
#  'шпигель_NOUN',
#  'становиться_VERB',
#  'фигурант_NOUN',
#  'семейный_ADJ',
#  'скандал_NOUN',
#  '._PUNCT',
#  'когда_CONJ',
#  'реалия_NOUN',
#  'современный_ADJ',
#  'российский_ADJ',
#  'политика_NOUN',
#  'изменяться_VERB',
#  ',_PUNCT',
#  'бизнесмен_NOUN',
#  'не_PART',
#  'пожелать_ADVPARTICIPLE',
#  'отказываться_INFN',
#  'от_PREP',
#  'зарубежный_ADJ',
#  'вклад_NOUN',
#  'и_CONJ',
#  'терять_INFN',
#  'израильский_ADJ',
#  'гражданство_NOUN',
#  '._PUNCT',
#  'поэтому_ADV_PRONOUN',
#  'покидать_VERB',
#  'совет_NOUN',
#  'федерация_NOUN',
#  'и_CONJ',
#  'продолжать_VERB',
#  'активно_ADV',
#  'заниматься_INFN',
#  'общественный_ADJ',
#  'деятельность_NOUN',
#  'во_PREP',
#  'глава_NOUN',
#  'существующий_ADJ',
#  'за_PREP',
#  'его_ADJ_PRONOUN',
#  'счет_NOUN',
#  'общественный_ADJ',
#  'организация_NOUN',
#  '"_PUNCT',
#  'мир_NOUN',
#  'без_PREP',
#  'нацизм_NOUN',
#  '",_X',
#  'передвигаться_ADVPARTICIPLE',
#  'между_PREP',
#  'свой_ADJ_PRONOUN',
#  'вилл_NOUN',
#  'в_PREP',
#  'италия_NOUN',
#  'и_CONJ',
#  'израиль_NOUN',
#  '._PUNCT',
#  '6_X',
#  'место_NOUN',
#  '._PUNCT',
#  'игорь_NOUN',
#  'юсуфов_NOUN',
#  '._PUNCT',
#  'в_PREP',
#  'отличие_NOUN',
#  'от_PREP',
#  'шпигель_NOUN',
#  ',_PUNCT',
#  'бывший_ADJ',
#  'министр_NOUN',
#  'энергетика_NOUN',
#  'рф_NOUN',
#  'игорь_NOUN',
#  'юсуфов_NOUN',
#  'предпочитать_VERB',
#  'не_PART',
#  'реагировать_INFN',
#  'на_PREP',
#  'скандальный_ADJ',
#  'разоблачение_NOUN',
#  '._PUNCT',
#  'когда_CONJ',
#  'еще_ADV',
#  'в_PREP',
#  '2002_X',
#  'год_NOUN',
#  'происходить_VERB',
#  'скандал_NOUN',
#  ',_PUNCT',
#  'связывать_PARTICIPLE',
#  'с_PREP',
#  'попытка_NOUN',
#  ...]

# %%
word = 'дмитрий_X'
import re
for i in ['_PREP', '_X', '_ADJ_PRONOUN', '_PUNCT', '_NOUN_PRONOUN', '_CONJ']:
    pattern = re.compile(i)
    if pattern.search(word):
        word = pattern.sub('', word)
        break
word
# Out:
# _PREP
# 'дмитрий'

# %%
word = 'дмитрий_PREP'
pattern = re.compile('_PREP')
if pattern.search(word):
    print('a')
# Out:
# a

# %%
word = 'дмитрий_X'
word = re.sub('_.*','', word)
word
# Out:
# 'дмитрий'

# %%
tdm = textmining.TermDocumentMatrix()
for i in range(len(documents_with_marked_terms)):
    tdm.add_doc(documents_with_marked_terms[i])
# Out:
# []
# []

# %%
marked_terms = []
for i in range(len(paragraph_with_marked_terms)):
    if i > 100:
        break
    for word in paragraph_with_marked_terms[i].split():
        marked_terms.append(word)
    i = i + 1
